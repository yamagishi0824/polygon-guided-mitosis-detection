# %%
import os

import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns

# %%
train = pd.read_csv("/kaggle/input/data-preprocessing/train_pngs/regions_metadata.csv")
train
# Out:
#                 filename                                      original_json  \
# 0     training0967_0.png  /kaggle/input/glioma-mcd-2025/Glioma_MDC_2025_...
# 1     training0991_0.png  /kaggle/input/glioma-mcd-2025/Glioma_MDC_2025_...
# 2     training0676_0.png  /kaggle/input/glioma-mcd-2025/Glioma_MDC_2025_...
# 3     training0325_0.png  /kaggle/input/glioma-mcd-2025/Glioma_MDC_2025_...
# 4     training1027_0.png  /kaggle/input/glioma-mcd-2025/Glioma_MDC_2025_...
# ...                  ...                                                ...
# 1608  training0685_0.png  /kaggle/input/glioma-mcd-2025/Glioma_MDC_2025_...
# 1609  training1421_0.png  /kaggle/input/glioma-mcd-2025/Glioma_MDC_2025_...
# 1610  training0533_0.png  /kaggle/input/glioma-mcd-2025/Glioma_MDC_2025_...
# 1611  training1182_0.png  /kaggle/input/glioma-mcd-2025/Glioma_MDC_2025_...
# 1612  training0557_0.png  /kaggle/input/glioma-mcd-2025/Glioma_MDC_2025_...
#
#             label  is_mitosis                  bbox region_size
# 0     Non-mitosis           1  [384, 183, 447, 250]    (63, 67)
# 1     Non-mitosis           1  [109, 397, 158, 445]    (49, 48)
# 2         Mitosis           1  [347, 411, 408, 461]    (61, 50)
# 3     Non-mitosis           1  [314, 415, 356, 455]    (42, 40)
# 4     Non-mitosis           1  [286, 242, 347, 308]    (61, 66)
# ...           ...         ...                   ...         ...
# 1608  Non-mitosis           1  [328, 313, 385, 377]    (57, 64)
# 1609      Mitosis           1  [202, 190, 283, 258]    (81, 68)
# 1610      Mitosis           1   [85, 241, 151, 301]    (66, 60)
# 1611  Non-mitosis           1  [295, 240, 360, 315]    (65, 75)
# 1612      Mitosis           1    [245, 39, 301, 93]    (56, 54)
#
# [1613 rows x 6 columns]

# %%
label_map = {"Non-mitosis": 0, "Mitosis": 1}
train = pd.read_csv("/kaggle/input/data-preprocessing-tr-122824/train_pngs/regions_metadata.csv")
train["Label"] = train["label"].map(label_map)
train
# Out:
#                 filename                                      original_json  \
# 0     training0967_0.png  /kaggle/input/glioma-mcd-2025/Data_122824/Glio...
# 1     training0991_0.png  /kaggle/input/glioma-mcd-2025/Data_122824/Glio...
# 2     training0676_0.png  /kaggle/input/glioma-mcd-2025/Data_122824/Glio...
# 3     training0325_0.png  /kaggle/input/glioma-mcd-2025/Data_122824/Glio...
# 4     training1027_0.png  /kaggle/input/glioma-mcd-2025/Data_122824/Glio...
# ...                  ...                                                ...
# 1611  training0685_0.png  /kaggle/input/glioma-mcd-2025/Data_122824/Glio...
# 1612  training1421_0.png  /kaggle/input/glioma-mcd-2025/Data_122824/Glio...
# 1613  training0533_0.png  /kaggle/input/glioma-mcd-2025/Data_122824/Glio...
# 1614  training1182_0.png  /kaggle/input/glioma-mcd-2025/Data_122824/Glio...
# 1615  training0557_0.png  /kaggle/input/glioma-mcd-2025/Data_122824/Glio...
#
#             label  is_mitosis                  bbox region_size  Label
# 0     Non-mitosis           1  [228, 130, 297, 202]    (69, 72)      0
# 1         Mitosis           1   [51, 170, 110, 214]    (59, 44)      1
# 2     Non-mitosis           1   [65, 167, 123, 220]    (58, 53)      0
# 3     Non-mitosis           1  [281, 213, 327, 256]    (46, 43)      0
# 4     Non-mitosis           1  [319, 271, 391, 342]    (72, 71)      0
# ...           ...         ...                   ...         ...    ...
# 1611  Non-mitosis           1    [21, 345, 87, 405]    (66, 60)      0
# 1612  Non-mitosis           1  [268, 305, 344, 382]    (76, 77)      0
# 1613  Non-mitosis           1  [168, 236, 243, 302]    (75, 66)      0
# 1614  Non-mitosis           1   [324, 51, 392, 121]    (68, 70)      0
# 1615      Mitosis           1  [331, 364, 390, 422]    (59, 58)      1
#
# [1616 rows x 7 columns]

# %%
train["Study"] = train["filename"].apply(lambda x: x.split("_")[0])
train
# Out:
#                 filename                                      original_json  \
# 0     training0967_0.png  /kaggle/input/glioma-mcd-2025/Data_122824/Glio...
# 1     training0991_0.png  /kaggle/input/glioma-mcd-2025/Data_122824/Glio...
# 2     training0676_0.png  /kaggle/input/glioma-mcd-2025/Data_122824/Glio...
# 3     training0325_0.png  /kaggle/input/glioma-mcd-2025/Data_122824/Glio...
# 4     training1027_0.png  /kaggle/input/glioma-mcd-2025/Data_122824/Glio...
# ...                  ...                                                ...
# 1611  training0685_0.png  /kaggle/input/glioma-mcd-2025/Data_122824/Glio...
# 1612  training1421_0.png  /kaggle/input/glioma-mcd-2025/Data_122824/Glio...
# 1613  training0533_0.png  /kaggle/input/glioma-mcd-2025/Data_122824/Glio...
# 1614  training1182_0.png  /kaggle/input/glioma-mcd-2025/Data_122824/Glio...
# 1615  training0557_0.png  /kaggle/input/glioma-mcd-2025/Data_122824/Glio...
#
#             label  is_mitosis                  bbox region_size  Label  \
# 0     Non-mitosis           1  [228, 130, 297, 202]    (69, 72)      0
# 1         Mitosis           1   [51, 170, 110, 214]    (59, 44)      1
# 2     Non-mitosis           1   [65, 167, 123, 220]    (58, 53)      0
# 3     Non-mitosis           1  [281, 213, 327, 256]    (46, 43)      0
# 4     Non-mitosis           1  [319, 271, 391, 342]    (72, 71)      0
# ...           ...         ...                   ...         ...    ...
# 1611  Non-mitosis           1    [21, 345, 87, 405]    (66, 60)      0
# 1612  Non-mitosis           1  [268, 305, 344, 382]    (76, 77)      0
# 1613  Non-mitosis           1  [168, 236, 243, 302]    (75, 66)      0
# 1614  Non-mitosis           1   [324, 51, 392, 121]    (68, 70)      0
# 1615      Mitosis           1  [331, 364, 390, 422]    (59, 58)      1
#
#              Study
# 0     training0967
# 1     training0991
# 2     training0676
# 3     training0325
# 4     training1027
# ...            ...
# 1611  training0685
# 1612  training1421
# 1613  training0533
# 1614  training1182
# 1615  training0557
#
# [1616 rows x 8 columns]

# %% [markdown]
# # Directory settings

# %%
# ====================================================
# Directory settings
# ====================================================
import os

OUTPUT_DIR = './'
if not os.path.exists(OUTPUT_DIR):
    os.makedirs(OUTPUT_DIR)

TRAIN_PATH = '/kaggle/input/data-preprocessing-tr-122824/train_pngs/'
# TEST_PATH = '../input/cassava-leaf-disease-classification/test_images'

# %% [markdown]
# # CFG

# %%
# ====================================================
# CFG
# ====================================================
class CFG:
    debug=False
    apex=False
    print_freq=100
    num_workers=4
    model_name= 'convnextv2_base.fcmae_ft_in22k_in1k' #"maxvit_tiny_tf_224.in1k" #"tf_efficientnetv2_s.in21k_ft_in1k" #'tf_efficientnetv2_s.in21k_ft_in1k' #'convnextv2_tiny.fcmae_ft_in22k_in1k' #'tf_efficientnetv2_s.in21k_ft_in1k' #'resnext50_32x4d'
    size= 128
    scheduler='CosineAnnealingWarmRestarts' # ['ReduceLROnPlateau', 'CosineAnnealingLR', 'CosineAnnealingWarmRestarts']
    epochs=5
    #factor=0.2 # ReduceLROnPlateau
    #patience=4 # ReduceLROnPlateau
    #eps=1e-6 # ReduceLROnPlateau
    #T_max=10 # CosineAnnealingLR
    T_0=epochs # CosineAnnealingWarmRestarts
    lr=1e-4
    min_lr=1e-6
    batch_size=32
    weight_decay=1e-6
    gradient_accumulation_steps=1
    max_grad_norm=1000
    seed=42
    
    target_cols = ['Label']
    target_size= len(target_cols)
    target_col='target'
    n_fold=5
    trn_fold=[0,1,2,3,4]
    train=True
    inference=False
    
if CFG.debug:
    CFG.epochs = 1
    train = train.sample(n=1000, random_state=CFG.seed).reset_index(drop=True)

# %% [markdown]
# # Library

# %%
# ====================================================
# Library
# ====================================================
import sys
sys.path.append('../input/pytorch-image-models/pytorch-image-models-master')

import os
import math
import time
import random
import shutil
from pathlib import Path
from contextlib import contextmanager
from collections import defaultdict, Counter

import scipy as sp
import numpy as np
import pandas as pd

from sklearn import preprocessing
from sklearn.metrics import accuracy_score, roc_auc_score, f1_score
from sklearn.model_selection import StratifiedKFold, StratifiedGroupKFold

from tqdm.auto import tqdm
from functools import partial

import cv2
from PIL import Image

import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.optim import Adam, SGD
import torchvision.models as models
from torch.nn.parameter import Parameter
from torch.utils.data import DataLoader, Dataset
from torch.optim.lr_scheduler import CosineAnnealingWarmRestarts, CosineAnnealingLR, ReduceLROnPlateau

from albumentations import (
    Compose, OneOf, Normalize, Resize, RandomResizedCrop, RandomCrop, HorizontalFlip, VerticalFlip, 
    RandomBrightnessContrast, Rotate, ShiftScaleRotate, Transpose
    )
from albumentations.pytorch import ToTensorV2
from albumentations import ImageOnlyTransform

import timm

import warnings 
warnings.filterwarnings('ignore')

if CFG.apex:
    from apex import amp

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
# Out:
# /opt/conda/lib/python3.10/site-packages/albumentations/__init__.py:24: UserWarning: A new version of Albumentations is available: 1.4.24 (you have 1.4.21). Upgrade using: pip install -U albumentations. To disable automatic update checks, set the environment variable NO_ALBUMENTATIONS_UPDATE to 1.
#   check_for_updates()

# %% [markdown]
# # Utils

# %%
# ====================================================
# Utils
# ====================================================
def get_score(y_true, y_pred):
    return f1_score(y_true, y_pred)


@contextmanager
def timer(name):
    t0 = time.time()
    LOGGER.info(f'[{name}] start')
    yield
    LOGGER.info(f'[{name}] done in {time.time() - t0:.0f} s.')


def init_logger(log_file=OUTPUT_DIR+'train.log'):
    from logging import getLogger, INFO, FileHandler,  Formatter,  StreamHandler
    logger = getLogger(__name__)
    logger.setLevel(INFO)
    handler1 = StreamHandler()
    handler1.setFormatter(Formatter("%(message)s"))
    handler2 = FileHandler(filename=log_file)
    handler2.setFormatter(Formatter("%(message)s"))
    logger.addHandler(handler1)
    logger.addHandler(handler2)
    return logger

LOGGER = init_logger()


def seed_torch(seed=42):
    random.seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.backends.cudnn.deterministic = True

seed_torch(seed=CFG.seed)

# %% [markdown]
# # CV split

# %%
folds = train.copy()
Fold = StratifiedGroupKFold(n_splits=CFG.n_fold, shuffle=True, random_state=CFG.seed)
for n, (train_index, val_index) in enumerate(Fold.split(folds, folds["Label"], folds["Study"])):
    folds.loc[val_index, 'fold'] = int(n)
folds['fold'] = folds['fold'].astype(int)
folds
# Out:
#                 filename                                      original_json  \
# 0     training0967_0.png  /kaggle/input/glioma-mcd-2025/Data_122824/Glio...
# 1     training0991_0.png  /kaggle/input/glioma-mcd-2025/Data_122824/Glio...
# 2     training0676_0.png  /kaggle/input/glioma-mcd-2025/Data_122824/Glio...
# 3     training0325_0.png  /kaggle/input/glioma-mcd-2025/Data_122824/Glio...
# 4     training1027_0.png  /kaggle/input/glioma-mcd-2025/Data_122824/Glio...
# ...                  ...                                                ...
# 1611  training0685_0.png  /kaggle/input/glioma-mcd-2025/Data_122824/Glio...
# 1612  training1421_0.png  /kaggle/input/glioma-mcd-2025/Data_122824/Glio...
# 1613  training0533_0.png  /kaggle/input/glioma-mcd-2025/Data_122824/Glio...
# 1614  training1182_0.png  /kaggle/input/glioma-mcd-2025/Data_122824/Glio...
# 1615  training0557_0.png  /kaggle/input/glioma-mcd-2025/Data_122824/Glio...
#
#             label  is_mitosis                  bbox region_size  Label  \
# 0     Non-mitosis           1  [228, 130, 297, 202]    (69, 72)      0
# 1         Mitosis           1   [51, 170, 110, 214]    (59, 44)      1
# 2     Non-mitosis           1   [65, 167, 123, 220]    (58, 53)      0
# 3     Non-mitosis           1  [281, 213, 327, 256]    (46, 43)      0
# 4     Non-mitosis           1  [319, 271, 391, 342]    (72, 71)      0
# ...           ...         ...                   ...         ...    ...
# 1611  Non-mitosis           1    [21, 345, 87, 405]    (66, 60)      0
# 1612  Non-mitosis           1  [268, 305, 344, 382]    (76, 77)      0
# 1613  Non-mitosis           1  [168, 236, 243, 302]    (75, 66)      0
# 1614  Non-mitosis           1   [324, 51, 392, 121]    (68, 70)      0
# 1615      Mitosis           1  [331, 364, 390, 422]    (59, 58)      1
#
#              Study  fold
# 0     training0967     4
# 1     training0991     4
# 2     training0676     1
# 3     training0325     4
# 4     training1027     3
# ...            ...   ...
# 1611  training0685     4
# 1612  training1421     1
# 1613  training0533     3
# 1614  training1182     2
# 1615  training0557     4
#
# [1616 rows x 9 columns]

# %%
folds["Label"].value_counts()
# Out:
# Label
# 1    889
# 0    727
# Name: count, dtype: int64

# %% [markdown]
# # Dataset

# %%
import pydicom
# ====================================================
# Dataset
# ====================================================
class TrainDataset(Dataset):
    def __init__(self, df, transform=None):
        self.df = df
        self.file_paths = df['filename'].values
        self.labels = df[CFG.target_cols].values
        self.transform = transform
        
    def __len__(self):
        return len(self.df)

    def __getitem__(self, idx):
        file_path = TRAIN_PATH + self.file_paths[idx]
        image = cv2.imread(file_path)
        image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
        if self.transform:
            augmented = self.transform(image=image)
            image = augmented['image']
        label = torch.tensor(self.labels[idx]).float()
        return image, label
    

class TestDataset(Dataset):
    def __init__(self, df, transform=None):
        self.df = df
        self.file_names = df['image_id'].values
        self.transform = transform
        
    def __len__(self):
        return len(self.df)

    def __getitem__(self, idx):
        file_name = self.file_names[idx]
        file_path = f'{TEST_PATH}/{file_name}'
        image = cv2.imread(file_path)
        image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
        if self.transform:
            augmented = self.transform(image=image)
            image = augmented['image']
        return image

# %%
train_dataset = TrainDataset(train, transform=None)

for i in range(10):
    image, label = train_dataset[i]
    plt.imshow(image)
    plt.title(f'label: {label}')
    plt.show()

# %% [markdown]
# # Transforms

# %%
# ====================================================
# Transforms
# ====================================================
def get_transforms(*, data):
    
    if data == 'train':
        return Compose([
            Resize(CFG.size, CFG.size),
            #RandomResizedCrop(CFG.size, CFG.size),
            Transpose(p=0.5),
            HorizontalFlip(p=0.5),
            VerticalFlip(p=0.5),
            ShiftScaleRotate(p=0.5),
            Normalize(
                mean=[0.485, 0.456, 0.406],
                std=[0.229, 0.224, 0.225],
            ),
            ToTensorV2(),
        ])

    elif data == 'valid':
        return Compose([
            Resize(CFG.size, CFG.size),
            Normalize(
                mean=[0.485, 0.456, 0.406],
                std=[0.229, 0.224, 0.225],
            ),
            ToTensorV2(),
        ])

# %%
train_dataset = TrainDataset(train, transform=get_transforms(data='train'))

for i in range(1):
    image, label = train_dataset[i]
    plt.imshow(image[0])
    plt.title(f'label: {label}')
    plt.show()

# %% [markdown]
# # MODEL

# %%
# ====================================================
# MODEL
# ====================================================
class CustomResNext(nn.Module):
    def __init__(self, model_name='resnext50_32x4d', pretrained=False):
        super().__init__()
        self.model = timm.create_model(model_name, pretrained=pretrained)
        n_features = self.model.fc.in_features
        self.model.fc = nn.Linear(n_features, 1)

    def forward(self, x):
        x = self.model(x)
        return x

# %%
#model = CustomResNext(model_name=CFG.model_name, pretrained=False)
model = timm.create_model(model_name=CFG.model_name, num_classes=1)
train_dataset = TrainDataset(train, transform=get_transforms(data='train'))
train_loader = DataLoader(train_dataset, batch_size=4, shuffle=True,
                          num_workers=4, pin_memory=True, drop_last=True)

for image, label in train_loader:
    output = model(image)
    print(output)
    break
# Out:
# tensor([[0.2628],
#         [1.0803],
#         [0.9294],
#         [1.0311]], grad_fn=<AddmmBackward0>)

# %% [markdown]
# # Helper functions

# %%
# ====================================================
# Helper functions
# ====================================================
class AverageMeter(object):
    """Computes and stores the average and current value"""
    def __init__(self):
        self.reset()

    def reset(self):
        self.val = 0
        self.avg = 0
        self.sum = 0
        self.count = 0

    def update(self, val, n=1):
        self.val = val
        self.sum += val * n
        self.count += n
        self.avg = self.sum / self.count


def asMinutes(s):
    m = math.floor(s / 60)
    s -= m * 60
    return '%dm %ds' % (m, s)


def timeSince(since, percent):
    now = time.time()
    s = now - since
    es = s / (percent)
    rs = es - s
    return '%s (remain %s)' % (asMinutes(s), asMinutes(rs))


def train_fn(train_loader, model, criterion, optimizer, epoch, scheduler, device):
    batch_time = AverageMeter()
    data_time = AverageMeter()
    losses = AverageMeter()
    scores = AverageMeter()
    # switch to train mode
    model.train()
    start = end = time.time()
    global_step = 0
    for step, (images, labels) in enumerate(train_loader):
        # measure data loading time
        data_time.update(time.time() - end)
        images = images.to(device)
        labels = labels.to(device)
        batch_size = labels.size(0)
        y_preds = model(images)
        loss = criterion(y_preds, labels)
        # record loss
        losses.update(loss.item(), batch_size)
        if CFG.gradient_accumulation_steps > 1:
            loss = loss / CFG.gradient_accumulation_steps
        if CFG.apex:
            with amp.scale_loss(loss, optimizer) as scaled_loss:
                scaled_loss.backward()
        else:
            loss.backward()
        grad_norm = torch.nn.utils.clip_grad_norm_(model.parameters(), CFG.max_grad_norm)
        if (step + 1) % CFG.gradient_accumulation_steps == 0:
            optimizer.step()
            optimizer.zero_grad()
            global_step += 1
        # measure elapsed time
        batch_time.update(time.time() - end)
        end = time.time()
        if step % CFG.print_freq == 0 or step == (len(train_loader)-1):
            print('Epoch: [{0}][{1}/{2}] '
                  'Data {data_time.val:.3f} ({data_time.avg:.3f}) '
                  'Elapsed {remain:s} '
                  'Loss: {loss.val:.4f}({loss.avg:.4f}) '
                  'Grad: {grad_norm:.4f}  '
                  #'LR: {lr:.6f}  '
                  .format(
                   epoch+1, step, len(train_loader), batch_time=batch_time,
                   data_time=data_time, loss=losses,
                   remain=timeSince(start, float(step+1)/len(train_loader)),
                   grad_norm=grad_norm,
                   #lr=scheduler.get_lr()[0],
                   ))
    return losses.avg


def valid_fn(valid_loader, model, criterion, device):
    batch_time = AverageMeter()
    data_time = AverageMeter()
    losses = AverageMeter()
    scores = AverageMeter()
    # switch to evaluation mode
    model.eval()
    preds = []
    start = end = time.time()
    for step, (images, labels) in enumerate(valid_loader):
        # measure data loading time
        data_time.update(time.time() - end)
        images = images.to(device)
        labels = labels.to(device)
        batch_size = labels.size(0)
        # compute loss
        with torch.no_grad():
            y_preds = model(images)
        loss = criterion(y_preds, labels)
        losses.update(loss.item(), batch_size)
        # record accuracy
        preds.append(y_preds.sigmoid().to('cpu').numpy())
        # preds.append(y_preds.to('cpu').numpy())
        if CFG.gradient_accumulation_steps > 1:
            loss = loss / CFG.gradient_accumulation_steps
        # measure elapsed time
        batch_time.update(time.time() - end)
        end = time.time()
        if step % CFG.print_freq == 0 or step == (len(valid_loader)-1):
            print('EVAL: [{0}/{1}] '
                  'Data {data_time.val:.3f} ({data_time.avg:.3f}) '
                  'Elapsed {remain:s} '
                  'Loss: {loss.val:.4f}({loss.avg:.4f}) '
                  .format(
                   step, len(valid_loader), batch_time=batch_time,
                   data_time=data_time, loss=losses,
                   remain=timeSince(start, float(step+1)/len(valid_loader)),
                   ))
    predictions = np.concatenate(preds)
    return losses.avg, predictions


def inference(model, states, test_loader, device):
    model.to(device)
    tk0 = tqdm(enumerate(test_loader), total=len(test_loader))
    probs = []
    for i, (images) in tk0:
        images = images.to(device)
        avg_preds = []
        for state in states:
            model.load_state_dict(state['model'])
            model.eval()
            with torch.no_grad():
                y_preds = model(images)
            avg_preds.append(y_preds.to('cpu').numpy())
        avg_preds = np.mean(avg_preds, axis=0)
        probs.append(avg_preds)
    probs = np.concatenate(probs)
    return probs

# %% [markdown]
# # Train loop

# %%
# ====================================================
# Train loop
# ====================================================
def train_loop(folds, fold):

    LOGGER.info(f"========== fold: {fold} training ==========")

    # ====================================================
    # loader
    # ====================================================
    trn_idx = folds[folds['fold'] != fold].index
    val_idx = folds[folds['fold'] == fold].index

    train_folds = folds.loc[trn_idx].reset_index(drop=True)
    valid_folds = folds.loc[val_idx].reset_index(drop=True)

    train_dataset = TrainDataset(train_folds, 
                                 transform=get_transforms(data='train'))
    valid_dataset = TrainDataset(valid_folds, 
                                 transform=get_transforms(data='valid'))

    train_loader = DataLoader(train_dataset, 
                              batch_size=CFG.batch_size, 
                              shuffle=True, 
                              num_workers=CFG.num_workers, pin_memory=True, drop_last=True)
    valid_loader = DataLoader(valid_dataset, 
                              batch_size=CFG.batch_size, 
                              shuffle=False, 
                              num_workers=CFG.num_workers, pin_memory=True, drop_last=False)
    
    # ====================================================
    # scheduler 
    # ====================================================
    def get_scheduler(optimizer):
        if CFG.scheduler=='ReduceLROnPlateau':
            scheduler = ReduceLROnPlateau(optimizer, mode='min', factor=CFG.factor, patience=CFG.patience, verbose=True, eps=CFG.eps)
        elif CFG.scheduler=='CosineAnnealingLR':
            scheduler = CosineAnnealingLR(optimizer, T_max=CFG.T_max, eta_min=CFG.min_lr, last_epoch=-1)
        elif CFG.scheduler=='CosineAnnealingWarmRestarts':
            scheduler = CosineAnnealingWarmRestarts(optimizer, T_0=CFG.T_0, T_mult=1, eta_min=CFG.min_lr, last_epoch=-1)
        return scheduler

    # ====================================================
    # model & optimizer
    # ====================================================
    # model = CustomResNext(CFG.model_name, pretrained=True)
    model = timm.create_model(model_name=CFG.model_name, num_classes=CFG.target_size, pretrained=True)
    model.to(device)

    optimizer = Adam(model.parameters(), lr=CFG.lr, weight_decay=CFG.weight_decay, amsgrad=False)
    scheduler = get_scheduler(optimizer)

    # ====================================================
    # apex
    # ====================================================
    if CFG.apex:
        model, optimizer = amp.initialize(model, optimizer, opt_level='O1', verbosity=0)

    # ====================================================
    # loop
    # ====================================================
    # criterion = nn.CrossEntropyLoss()
    criterion = nn.BCEWithLogitsLoss()

    best_score = 0.
    best_loss = np.inf
    
    for epoch in range(CFG.epochs):
        
        start_time = time.time()
        
        # train
        avg_loss = train_fn(train_loader, model, criterion, optimizer, epoch, scheduler, device)

        # eval
        avg_val_loss, preds = valid_fn(valid_loader, model, criterion, device)
        valid_labels = valid_folds[CFG.target_cols].values
        
        if isinstance(scheduler, ReduceLROnPlateau):
            scheduler.step(avg_val_loss)
        elif isinstance(scheduler, CosineAnnealingLR):
            scheduler.step()
        elif isinstance(scheduler, CosineAnnealingWarmRestarts):
            scheduler.step()

        # scoring
        score = get_score(valid_labels, preds > 0.5)

        elapsed = time.time() - start_time

        LOGGER.info(f'Epoch {epoch+1} - avg_train_loss: {avg_loss:.4f}  avg_val_loss: {avg_val_loss:.4f}  time: {elapsed:.0f}s')
        # LOGGER.info(f'Epoch {epoch+1} - Accuracy: {score}')

        if score > best_score:
            best_score = score
            LOGGER.info(f'Epoch {epoch+1} - Save Best Score: {best_score:.4f} Model')
            torch.save({'model': model.state_dict(), 
                        'preds': preds},
                        OUTPUT_DIR+f'{CFG.model_name}_fold{fold}_best.pth')
            
        if avg_val_loss < best_loss:
            best_loss = avg_val_loss
            LOGGER.info(f'Epoch {epoch+1} - Save Best Loss: {best_loss:.4f} Model')
            torch.save({'model': model.state_dict(), 
                        'preds': preds},
                        OUTPUT_DIR+f'{CFG.model_name}_fold{fold}_best_loss.pth')
    
    check_point = torch.load(OUTPUT_DIR+f'{CFG.model_name}_fold{fold}_best_loss.pth')
    valid_folds[[str(c) for c in range(CFG.target_size)]] = check_point['preds']

    return valid_folds

# %%
# ====================================================
# main
# ====================================================
def main():

    """
    Prepare: 1.train  2.test  3.submission  4.folds
    """

    def get_result(result_df):
        preds = result_df['preds'].values
        labels = result_df[CFG.target_col].values
        score = get_score(labels, preds)
        LOGGER.info(f'Score: {score:<.5f}')
    
    if CFG.train:
        # train 
        oof_df = pd.DataFrame()
        for fold in range(CFG.n_fold):
            if fold in CFG.trn_fold:
                _oof_df = train_loop(folds, fold)
                oof_df = pd.concat([oof_df, _oof_df])
                LOGGER.info(f"========== fold: {fold} result ==========")
                # get_result(_oof_df)
        # CV result
        # LOGGER.info(f"========== CV ==========")
        # get_result(oof_df)
        # save result
        oof_df.to_csv(OUTPUT_DIR+'oof_df.csv', index=False)
    
    if CFG.inference:
        # inference
        model = CustomResNext(CFG.model_name, pretrained=False)
        states = [torch.load(OUTPUT_DIR+f'{CFG.model_name}_fold{fold}_best.pth') for fold in CFG.trn_fold]
        test_dataset = TestDataset(test, transform=get_transforms(data='valid'))
        test_loader = DataLoader(test_dataset, batch_size=CFG.batch_size, shuffle=False, 
                                 num_workers=CFG.num_workers, pin_memory=True)
        predictions = inference(model, states, test_loader, device)
        # submission
        test['label'] = predictions.argmax(1)
        test[['image_id', 'label']].to_csv(OUTPUT_DIR+'submission.csv', index=False)

# %%
import gc

if __name__ == '__main__':
    torch.cuda.empty_cache()
    gc.collect()
    main()
# Out:
# ========== fold: 0 training ==========
# model.safetensors:   0%|          | 0.00/355M [00:00<?, ?B/s]
# Epoch: [1][0/40] Data 0.374 (0.374) Elapsed 0m 2s (remain 1m 32s) Loss: 0.6886(0.6886) Grad: 10.5977
# Epoch: [1][39/40] Data 0.000 (0.010) Elapsed 0m 29s (remain 0m 0s) Loss: 0.1725(0.1493) Grad: 19.4639
# EVAL: [0/11] Data 0.357 (0.357) Elapsed 0m 0s (remain 0m 4s) Loss: 0.3171(0.3171)
# Epoch 1 - avg_train_loss: 0.1493  avg_val_loss: 0.1060  time: 31s
# Epoch 1 - Save Best Score: 0.9628 Model
# EVAL: [10/11] Data 0.000 (0.033) Elapsed 0m 1s (remain 0m 0s) Loss: 0.1114(0.1060)
# Epoch 1 - Save Best Loss: 0.1060 Model
# Epoch: [2][0/40] Data 0.254 (0.254) Elapsed 0m 0s (remain 0m 32s) Loss: 0.0488(0.0488) Grad: 10.8780
# Epoch: [2][39/40] Data 0.000 (0.010) Elapsed 0m 28s (remain 0m 0s) Loss: 0.0100(0.0454) Grad: 1.3747
# EVAL: [0/11] Data 0.248 (0.248) Elapsed 0m 0s (remain 0m 3s) Loss: 0.2632(0.2632)
# Epoch 2 - avg_train_loss: 0.0454  avg_val_loss: 0.0932  time: 30s
# Epoch 2 - Save Best Score: 0.9781 Model
# EVAL: [10/11] Data 0.000 (0.023) Elapsed 0m 1s (remain 0m 0s) Loss: 0.0063(0.0932)
# Epoch 2 - Save Best Loss: 0.0932 Model
# Epoch: [3][0/40] Data 0.257 (0.257) Elapsed 0m 0s (remain 0m 32s) Loss: 0.0245(0.0245) Grad: 8.9348
# Epoch: [3][39/40] Data 0.000 (0.010) Elapsed 0m 28s (remain 0m 0s) Loss: 0.0106(0.0274) Grad: 11.0741
# EVAL: [0/11] Data 0.264 (0.264) Elapsed 0m 0s (remain 0m 3s) Loss: 0.2569(0.2569)
# Epoch 3 - avg_train_loss: 0.0274  avg_val_loss: 0.0298  time: 30s
# Epoch 3 - Save Best Score: 0.9972 Model
# EVAL: [10/11] Data 0.000 (0.024) Elapsed 0m 1s (remain 0m 0s) Loss: 0.0013(0.0298)
# Epoch 3 - Save Best Loss: 0.0298 Model
# Epoch: [4][0/40] Data 0.261 (0.261) Elapsed 0m 0s (remain 0m 32s) Loss: 0.0070(0.0070) Grad: 2.9064
# Epoch: [4][39/40] Data 0.000 (0.010) Elapsed 0m 28s (remain 0m 0s) Loss: 0.0012(0.0207) Grad: 0.0941
# EVAL: [0/11] Data 0.251 (0.251) Elapsed 0m 0s (remain 0m 3s) Loss: 0.2523(0.2523)
# Epoch 4 - avg_train_loss: 0.0207  avg_val_loss: 0.0897  time: 30s
# EVAL: [10/11] Data 0.000 (0.023) Elapsed 0m 1s (remain 0m 0s) Loss: 0.0004(0.0897)
# Epoch: [5][0/40] Data 0.249 (0.249) Elapsed 0m 0s (remain 0m 32s) Loss: 0.1752(0.1752) Grad: 5.5887
# Epoch: [5][39/40] Data 0.000 (0.010) Elapsed 0m 28s (remain 0m 0s) Loss: 0.1500(0.0229) Grad: 8.5757
# EVAL: [0/11] Data 0.245 (0.245) Elapsed 0m 0s (remain 0m 3s) Loss: 0.2594(0.2594)
# Epoch 5 - avg_train_loss: 0.0229  avg_val_loss: 0.0391  time: 30s
# EVAL: [10/11] Data 0.000 (0.023) Elapsed 0m 1s (remain 0m 0s) Loss: 0.0011(0.0391)
# ========== fold: 0 result ==========
# ========== fold: 1 training ==========
# Epoch: [1][0/40] Data 0.271 (0.271) Elapsed 0m 0s (remain 0m 38s) Loss: 0.6340(0.6340) Grad: 8.3018
# Epoch: [1][39/40] Data 0.000 (0.007) Elapsed 0m 28s (remain 0m 0s) Loss: 0.0042(0.0907) Grad: 1.1356
# EVAL: [0/11] Data 0.248 (0.248) Elapsed 0m 0s (remain 0m 3s) Loss: 0.0045(0.0045)
# Epoch 1 - avg_train_loss: 0.0907  avg_val_loss: 0.0570  time: 30s
# Epoch 1 - Save Best Score: 0.9853 Model
# EVAL: [10/11] Data 0.000 (0.023) Elapsed 0m 1s (remain 0m 0s) Loss: 0.0014(0.0570)
# Epoch 1 - Save Best Loss: 0.0570 Model
# Epoch: [2][0/40] Data 0.283 (0.283) Elapsed 0m 0s (remain 0m 33s) Loss: 0.0123(0.0123) Grad: 7.1511
# Epoch: [2][39/40] Data 0.000 (0.010) Elapsed 0m 28s (remain 0m 0s) Loss: 0.0342(0.0594) Grad: 6.3008
# EVAL: [0/11] Data 0.241 (0.241) Elapsed 0m 0s (remain 0m 3s) Loss: 0.0941(0.0941)
# Epoch 2 - avg_train_loss: 0.0594  avg_val_loss: 0.0593  time: 30s
# EVAL: [10/11] Data 0.000 (0.022) Elapsed 0m 1s (remain 0m 0s) Loss: 0.0105(0.0593)
# Epoch: [3][0/40] Data 0.268 (0.268) Elapsed 0m 0s (remain 0m 33s) Loss: 0.0091(0.0091) Grad: 0.7694
# Epoch: [3][39/40] Data 0.000 (0.010) Elapsed 0m 28s (remain 0m 0s) Loss: 0.0035(0.0407) Grad: 0.1516
# EVAL: [0/11] Data 0.240 (0.240) Elapsed 0m 0s (remain 0m 3s) Loss: 0.0776(0.0776)
# Epoch 3 - avg_train_loss: 0.0407  avg_val_loss: 0.0909  time: 30s
# EVAL: [10/11] Data 0.000 (0.022) Elapsed 0m 1s (remain 0m 0s) Loss: 0.0046(0.0909)
# Epoch: [4][0/40] Data 0.276 (0.276) Elapsed 0m 0s (remain 0m 33s) Loss: 0.0084(0.0084) Grad: 1.2835
# Epoch: [4][39/40] Data 0.000 (0.010) Elapsed 0m 28s (remain 0m 0s) Loss: 0.0018(0.0187) Grad: 0.0650
# EVAL: [0/11] Data 0.243 (0.243) Elapsed 0m 0s (remain 0m 3s) Loss: 0.0136(0.0136)
# Epoch 4 - avg_train_loss: 0.0187  avg_val_loss: 0.0410  time: 30s
# Epoch 4 - Save Best Score: 0.9942 Model
# EVAL: [10/11] Data 0.000 (0.022) Elapsed 0m 1s (remain 0m 0s) Loss: 0.0026(0.0410)
# Epoch 4 - Save Best Loss: 0.0410 Model
# Epoch: [5][0/40] Data 0.255 (0.255) Elapsed 0m 0s (remain 0m 32s) Loss: 0.0018(0.0018) Grad: 0.0666
# Epoch: [5][39/40] Data 0.000 (0.010) Elapsed 0m 28s (remain 0m 0s) Loss: 0.0030(0.0216) Grad: 0.4356
# EVAL: [0/11] Data 0.232 (0.232) Elapsed 0m 0s (remain 0m 3s) Loss: 0.0043(0.0043)
# Epoch 5 - avg_train_loss: 0.0216  avg_val_loss: 0.0410  time: 30s
# Epoch 5 - Save Best Loss: 0.0410 Model
# EVAL: [10/11] Data 0.000 (0.021) Elapsed 0m 1s (remain 0m 0s) Loss: 0.0025(0.0410)
# ========== fold: 1 result ==========
# ========== fold: 2 training ==========
# Epoch: [1][0/40] Data 0.276 (0.276) Elapsed 0m 0s (remain 0m 38s) Loss: 0.7020(0.7020) Grad: 12.4771
# Epoch: [1][39/40] Data 0.000 (0.007) Elapsed 0m 28s (remain 0m 0s) Loss: 0.0256(0.1291) Grad: 6.1085
# EVAL: [0/10] Data 0.265 (0.265) Elapsed 0m 0s (remain 0m 3s) Loss: 0.0129(0.0129)
# Epoch 1 - avg_train_loss: 0.1291  avg_val_loss: 0.0540  time: 30s
# Epoch 1 - Save Best Score: 0.9888 Model
# EVAL: [9/10] Data 0.000 (0.027) Elapsed 0m 1s (remain 0m 0s) Loss: 0.0139(0.0540)
# Epoch 1 - Save Best Loss: 0.0540 Model
# Epoch: [2][0/40] Data 0.257 (0.257) Elapsed 0m 0s (remain 0m 32s) Loss: 0.0099(0.0099) Grad: 0.8829
# Epoch: [2][39/40] Data 0.000 (0.010) Elapsed 0m 28s (remain 0m 0s) Loss: 0.1949(0.0526) Grad: 10.5002
# EVAL: [0/10] Data 0.245 (0.245) Elapsed 0m 0s (remain 0m 3s) Loss: 0.0077(0.0077)
# Epoch 2 - avg_train_loss: 0.0526  avg_val_loss: 0.0327  time: 30s
# Epoch 2 - Save Best Score: 0.9915 Model
# EVAL: [9/10] Data 0.000 (0.025) Elapsed 0m 1s (remain 0m 0s) Loss: 0.0053(0.0327)
# Epoch 2 - Save Best Loss: 0.0327 Model
# Epoch: [3][0/40] Data 0.266 (0.266) Elapsed 0m 0s (remain 0m 32s) Loss: 0.0468(0.0468) Grad: 11.5851
# Epoch: [3][39/40] Data 0.000 (0.010) Elapsed 0m 28s (remain 0m 0s) Loss: 0.0082(0.0345) Grad: 2.6602
# EVAL: [0/10] Data 0.256 (0.256) Elapsed 0m 0s (remain 0m 3s) Loss: 0.0020(0.0020)
# Epoch 3 - avg_train_loss: 0.0345  avg_val_loss: 0.0411  time: 30s
# Epoch 3 - Save Best Score: 0.9944 Model
# EVAL: [9/10] Data 0.000 (0.026) Elapsed 0m 1s (remain 0m 0s) Loss: 0.0064(0.0411)
# Epoch: [4][0/40] Data 0.268 (0.268) Elapsed 0m 0s (remain 0m 33s) Loss: 0.0073(0.0073) Grad: 1.6905
# Epoch: [4][39/40] Data 0.000 (0.010) Elapsed 0m 28s (remain 0m 0s) Loss: 0.0020(0.0227) Grad: 0.1228
# EVAL: [0/10] Data 0.273 (0.273) Elapsed 0m 0s (remain 0m 3s) Loss: 0.0016(0.0016)
# Epoch 4 - avg_train_loss: 0.0227  avg_val_loss: 0.0440  time: 30s
# EVAL: [9/10] Data 0.000 (0.028) Elapsed 0m 1s (remain 0m 0s) Loss: 0.0099(0.0440)
# Epoch: [5][0/40] Data 0.270 (0.270) Elapsed 0m 0s (remain 0m 33s) Loss: 0.0037(0.0037) Grad: 0.3178
# Epoch: [5][39/40] Data 0.000 (0.010) Elapsed 0m 28s (remain 0m 0s) Loss: 0.0027(0.0182) Grad: 0.1773
# EVAL: [0/10] Data 0.260 (0.260) Elapsed 0m 0s (remain 0m 3s) Loss: 0.0016(0.0016)
# Epoch 5 - avg_train_loss: 0.0182  avg_val_loss: 0.0402  time: 30s
# EVAL: [9/10] Data 0.000 (0.026) Elapsed 0m 1s (remain 0m 0s) Loss: 0.0063(0.0402)
# ========== fold: 2 result ==========
# ========== fold: 3 training ==========
# Epoch: [1][0/40] Data 0.278 (0.278) Elapsed 0m 0s (remain 0m 38s) Loss: 0.7272(0.7272) Grad: 15.0911
# Epoch: [1][39/40] Data 0.000 (0.007) Elapsed 0m 28s (remain 0m 0s) Loss: 0.0055(0.1334) Grad: 0.6595
# EVAL: [0/11] Data 0.279 (0.279) Elapsed 0m 0s (remain 0m 3s) Loss: 0.0041(0.0041)
# Epoch 1 - avg_train_loss: 0.1334  avg_val_loss: 0.0509  time: 30s
# Epoch 1 - Save Best Score: 0.9919 Model
# EVAL: [10/11] Data 0.000 (0.026) Elapsed 0m 1s (remain 0m 0s) Loss: 0.0022(0.0509)
# Epoch 1 - Save Best Loss: 0.0509 Model
# Epoch: [2][0/40] Data 0.265 (0.265) Elapsed 0m 0s (remain 0m 33s) Loss: 0.0035(0.0035) Grad: 0.4682
# Epoch: [2][39/40] Data 0.000 (0.010) Elapsed 0m 28s (remain 0m 0s) Loss: 0.0385(0.0447) Grad: 14.6891
# EVAL: [0/11] Data 0.256 (0.256) Elapsed 0m 0s (remain 0m 3s) Loss: 0.0211(0.0211)
# Epoch 2 - avg_train_loss: 0.0447  avg_val_loss: 0.0460  time: 30s
# Epoch 2 - Save Best Loss: 0.0460 Model
# EVAL: [10/11] Data 0.000 (0.024) Elapsed 0m 1s (remain 0m 0s) Loss: 0.0089(0.0460)
# Epoch: [3][0/40] Data 0.279 (0.279) Elapsed 0m 0s (remain 0m 33s) Loss: 0.0117(0.0117) Grad: 0.6214
# Epoch: [3][39/40] Data 0.000 (0.010) Elapsed 0m 28s (remain 0m 0s) Loss: 0.0339(0.0421) Grad: 4.9022
# EVAL: [0/11] Data 0.271 (0.271) Elapsed 0m 0s (remain 0m 3s) Loss: 0.1111(0.1111)
# Epoch 3 - avg_train_loss: 0.0421  avg_val_loss: 0.1170  time: 30s
# EVAL: [10/11] Data 0.000 (0.025) Elapsed 0m 1s (remain 0m 0s) Loss: 0.0006(0.1170)
# Epoch: [4][0/40] Data 0.258 (0.258) Elapsed 0m 0s (remain 0m 32s) Loss: 0.0278(0.0278) Grad: 5.2494
# Epoch: [4][39/40] Data 0.000 (0.010) Elapsed 0m 28s (remain 0m 0s) Loss: 0.0483(0.0338) Grad: 9.3615
# EVAL: [0/11] Data 0.233 (0.233) Elapsed 0m 0s (remain 0m 3s) Loss: 0.0142(0.0142)
# Epoch 4 - avg_train_loss: 0.0338  avg_val_loss: 0.0365  time: 30s
# Epoch 4 - Save Best Score: 0.9946 Model
# EVAL: [10/11] Data 0.000 (0.022) Elapsed 0m 1s (remain 0m 0s) Loss: 0.0011(0.0365)
# Epoch 4 - Save Best Loss: 0.0365 Model
# Epoch: [5][0/40] Data 0.271 (0.271) Elapsed 0m 0s (remain 0m 33s) Loss: 0.0029(0.0029) Grad: 0.1431
# Epoch: [5][39/40] Data 0.000 (0.010) Elapsed 0m 28s (remain 0m 0s) Loss: 0.0070(0.0172) Grad: 0.8024
# EVAL: [0/11] Data 0.257 (0.257) Elapsed 0m 0s (remain 0m 3s) Loss: 0.0050(0.0050)
# Epoch 5 - avg_train_loss: 0.0172  avg_val_loss: 0.0384  time: 30s
# EVAL: [10/11] Data 0.000 (0.024) Elapsed 0m 1s (remain 0m 0s) Loss: 0.0008(0.0384)
# ========== fold: 3 result ==========
# ========== fold: 4 training ==========
# Epoch: [1][0/40] Data 0.300 (0.300) Elapsed 0m 0s (remain 0m 38s) Loss: 0.6762(0.6762) Grad: 10.1420
# Epoch: [1][39/40] Data 0.000 (0.008) Elapsed 0m 28s (remain 0m 0s) Loss: 0.0092(0.1336) Grad: 0.7958
# EVAL: [0/11] Data 0.265 (0.265) Elapsed 0m 0s (remain 0m 3s) Loss: 0.0106(0.0106)
# Epoch 1 - avg_train_loss: 0.1336  avg_val_loss: 0.0234  time: 30s
# Epoch 1 - Save Best Score: 0.9972 Model
# EVAL: [10/11] Data 0.000 (0.025) Elapsed 0m 1s (remain 0m 0s) Loss: 0.0048(0.0234)
# Epoch 1 - Save Best Loss: 0.0234 Model
# Epoch: [2][0/40] Data 0.323 (0.323) Elapsed 0m 0s (remain 0m 35s) Loss: 0.0551(0.0551) Grad: 6.7703
# Epoch: [2][39/40] Data 0.000 (0.011) Elapsed 0m 28s (remain 0m 0s) Loss: 0.0035(0.0506) Grad: 0.1879
# EVAL: [0/11] Data 0.249 (0.249) Elapsed 0m 0s (remain 0m 3s) Loss: 0.0087(0.0087)
# Epoch 2 - avg_train_loss: 0.0506  avg_val_loss: 0.0405  time: 30s
# EVAL: [10/11] Data 0.000 (0.023) Elapsed 0m 1s (remain 0m 0s) Loss: 0.0022(0.0405)
# Epoch: [3][0/40] Data 0.305 (0.305) Elapsed 0m 0s (remain 0m 34s) Loss: 0.0104(0.0104) Grad: 3.6161
# Epoch: [3][39/40] Data 0.000 (0.011) Elapsed 0m 28s (remain 0m 0s) Loss: 0.0585(0.0307) Grad: 10.4382
# EVAL: [0/11] Data 0.257 (0.257) Elapsed 0m 0s (remain 0m 3s) Loss: 0.1573(0.1573)
# Epoch 3 - avg_train_loss: 0.0307  avg_val_loss: 0.1595  time: 30s
# EVAL: [10/11] Data 0.000 (0.024) Elapsed 0m 1s (remain 0m 0s) Loss: 0.0052(0.1595)
# Epoch: [4][0/40] Data 0.295 (0.295) Elapsed 0m 0s (remain 0m 34s) Loss: 0.0726(0.0726) Grad: 27.9551
# Epoch: [4][39/40] Data 0.000 (0.011) Elapsed 0m 28s (remain 0m 0s) Loss: 0.0104(0.0335) Grad: 0.6145
# EVAL: [0/11] Data 0.266 (0.266) Elapsed 0m 0s (remain 0m 3s) Loss: 0.0128(0.0128)
# Epoch 4 - avg_train_loss: 0.0335  avg_val_loss: 0.0336  time: 30s
# EVAL: [10/11] Data 0.000 (0.024) Elapsed 0m 1s (remain 0m 0s) Loss: 0.0011(0.0336)
# Epoch: [5][0/40] Data 0.285 (0.285) Elapsed 0m 0s (remain 0m 33s) Loss: 0.0202(0.0202) Grad: 1.4548
# Epoch: [5][39/40] Data 0.000 (0.011) Elapsed 0m 28s (remain 0m 0s) Loss: 0.0071(0.0213) Grad: 3.5604
# EVAL: [0/11] Data 0.256 (0.256) Elapsed 0m 0s (remain 0m 3s) Loss: 0.0048(0.0048)
# Epoch 5 - avg_train_loss: 0.0213  avg_val_loss: 0.0284  time: 30s
# EVAL: [10/11] Data 0.000 (0.024) Elapsed 0m 1s (remain 0m 0s) Loss: 0.0012(0.0284)
# ========== fold: 4 result ==========

# %%
oof = pd.read_csv("/kaggle/working/oof_df.csv")
oof
# Out:
#                 filename                                      original_json  \
# 0     training0657_0.png  /kaggle/input/glioma-mcd-2025/Data_122824/Glio...
# 1     training0327_0.png  /kaggle/input/glioma-mcd-2025/Data_122824/Glio...
# 2     training0082_0.png  /kaggle/input/glioma-mcd-2025/Data_122824/Glio...
# 3     training0082_1.png  /kaggle/input/glioma-mcd-2025/Data_122824/Glio...
# 4     training1399_0.png  /kaggle/input/glioma-mcd-2025/Data_122824/Glio...
# ...                  ...                                                ...
# 1611  training0239_0.png  /kaggle/input/glioma-mcd-2025/Data_122824/Glio...
# 1612  training1091_0.png  /kaggle/input/glioma-mcd-2025/Data_122824/Glio...
# 1613  training0489_0.png  /kaggle/input/glioma-mcd-2025/Data_122824/Glio...
# 1614  training0685_0.png  /kaggle/input/glioma-mcd-2025/Data_122824/Glio...
# 1615  training0557_0.png  /kaggle/input/glioma-mcd-2025/Data_122824/Glio...
#
#             label  is_mitosis                  bbox region_size  Label  \
# 0         Mitosis           1  [168, 401, 217, 458]    (49, 57)      1
# 1     Non-mitosis           1  [186, 272, 222, 315]    (36, 43)      0
# 2     Non-mitosis           1  [543, 359, 598, 409]    (55, 50)      0
# 3         Mitosis           1  [188, 197, 243, 252]    (55, 55)      1
# 4     Non-mitosis           1   [59, 303, 129, 373]    (70, 70)      0
# ...           ...         ...                   ...         ...    ...
# 1611      Mitosis           1  [190, 265, 228, 299]    (38, 34)      1
# 1612      Mitosis           1  [170, 310, 234, 380]    (64, 70)      1
# 1613  Non-mitosis           1  [419, 197, 478, 260]    (59, 63)      0
# 1614  Non-mitosis           1    [21, 345, 87, 405]    (66, 60)      0
# 1615      Mitosis           1  [331, 364, 390, 422]    (59, 58)      1
#
#              Study  fold         0
# 0     training0657     0  0.999647
# 1     training0327     0  0.001037
# 2     training0082     0  0.002731
# 3     training0082     0  0.998515
# 4     training1399     0  0.000405
# ...            ...   ...       ...
# 1611  training0239     4  0.993873
# 1612  training1091     4  0.997180
# 1613  training0489     4  0.005331
# 1614  training0685     4  0.004539
# 1615  training0557     4  0.995207
#
# [1616 rows x 10 columns]

# %%
accuracy_score(oof["Label"], oof["0"] > 0.5)
# Out:
# 0.994430693069307

# %%
f1_score(oof["Label"], oof["0"] > 0.5)
# Out:
# 0.9949295774647888
